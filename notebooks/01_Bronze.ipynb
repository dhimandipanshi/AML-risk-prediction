# %%
# %sql
SELECT * FROM aml_risk_prediction.default.transaction
LIMIT 10

# %%
last_updated_date = '2019-01-01'

# %%
spark.sql(f"""SELECT * FROM aml_risk_prediction.default.transaction
WHERE `Timestamp` > '{last_updated_date}'""").createOrReplaceTempView('bronze_trans')

# %%
# %sql
SELECT * FROM bronze_trans

# %%
# %sql
CREATE OR REPLACE TABLE aml_risk_prediction.bronze.bronze_table
TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
AS 
SELECT * FROM bronze_trans

# %%
spark.sql("""SELECT * FROM aml_risk_prediction.default.accounts""").createOrReplaceTempView('bronze_accounts')

# %%
# %sql
SELECT * FROM bronze_accounts

# %%
# %sql
CREATE OR REPLACE TABLE aml_risk_prediction.bronze.bronze_table2
TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
AS
SELECT * FROM bronze_accounts
